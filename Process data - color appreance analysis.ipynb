# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### colors/values appearence analysis

# %% [markdown]
# read Excel files by quadrant

# %%
blackbox1_top_left_quadrant = pd.read_csv("blackbox2_top_left_quadrant.csv",index_col=0)
blackbox1_top_right_quadrant = pd.read_csv("blackbox2_top_right_quadrant.csv",index_col=0)
blackbox1_bottom_left_quadrant = pd.read_csv("blackbox2_bottom_left_quadrant.csv",index_col=0)
blackbox1_bottom_right_quadrant = pd.read_csv("blackbox2_bottom_right_quadrant.csv",index_col=0)

# %% [markdown]
# find missing value by step

# %%
l = [1,2,3,4,5,6,7,8,9,0]                #a list contain all values

# %%
blackbox1_top_left_quadrant.head(5)
# Out:
#          ( 1, 1)  ( 1, 2)  ( 1, 3)  ( 1, 4)  ( 1, 5)  ( 1, 6)  ( 1, 7)  \
# step: 1        3        7        0        9        6        1        3
# step: 2        3        7        0        9        6        1        3
# step: 3        3        7        0        9        5        1        3
# step: 4        3        7        0        9        5        1        3
# step: 5        3        7        0        9        5        1        3
#
#          ( 1, 8)  ( 1, 9)  ( 1, 10)    ...      ( 10, 1)  ( 10, 2)  ( 10, 3)  \
# step: 1        3        4         8    ...             8         9         6
# step: 2        3        4         8    ...             8         9         6
# step: 3        3        4         8    ...             8         9         6
# step: 4        3        4         8    ...             8         9         6
# step: 5        3        4         8    ...             8         9         6
#
# ...

# %%
row = []
missing_value = []
blackbox1_top_left_quadrant["missing values"] = np.nan*4000
for row_index in range(4000):
    row = blackbox1_top_left_quadrant.iloc[row_index, 1:].tolist() #extract a row
    row = np.unique(row)     #get unique values from current row
    #print(row)
    missing_value = list(set(l)-set(row))    #find missing colors/values
    blackbox1_top_left_quadrant.loc[row_index,"missing values"] = [','.join(str(missing_value))]
    #print(','.join(missing_value))

# %%
row = []
missing_value = []
blackbox1_top_right_quadrant["missing values"] = np.nan*4000
for row_index in range(4000):
    row = blackbox1_top_right_quadrant.iloc[row_index, 1:].tolist() #extract a row
    row = np.unique(row)     #get unique values from current row
    #print(row)
    missing_value = list(set(l)-set(row))    #find missing colors/values
    blackbox1_top_right_quadrant.loc[row_index,"missing values"] = ','.join(str(missing_value))
    #print(','.join(missing_value))

# %%
row = []
missing_value = []
blackbox1_bottom_left_quadrant["missing values"] = np.nan*4000
for row_index in range(4000):
    row = blackbox1_bottom_left_quadrant.iloc[row_index, 1:].tolist() #extract a row
    row = np.unique(row)     #get unique values from current row
    #print(row)
    missing_value = list(set(l)-set(row))    #find missing colors/values
    blackbox1_bottom_left_quadrant.loc[row_index,"missing values"] = ','.join(str(missing_value))
    #print(','.join(missing_value))

# %%
row = []
missing_value = []
blackbox1_bottom_right_quadrant["missing values"] = np.nan*4000
for row_index in range(4000):
    row = blackbox1_bottom_right_quadrant.iloc[row_index, 1:].tolist() #extract a row
    row = np.unique(row)     #get unique values from current row
    #print(row)
    missing_value = list(set(l)-set(row))    #find missing colors/values
    blackbox1_bottom_right_quadrant.loc[row_index,"missing values"] = ','.join(str(missing_value))
    #print(','.join(missing_value))

# %%
blackbox1_bottom_left_quadrant.to_csv('file1.csv')
